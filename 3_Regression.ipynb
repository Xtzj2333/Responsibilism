# %%
import pandas as pd

df = pd.read_csv('data/df.csv')

# %%
df[['vandellocohencollectivismscore', 'responsibilism']].corr()
# Out:
#                                 vandellocohencollectivismscore  responsibilism
# vandellocohencollectivismscore                        1.000000        0.209397
# responsibilism                                        0.209397        1.000000

# %%
df.sort_values('vandellocohencollectivismscore', ascending=False)[['state', 'responsibilism']]
# Out:
#             state  responsibilism
# 10         hawaii        0.018659
# 17      louisiana       -0.088918
# 39  southcarolina       -0.021366
# 23    mississippi        0.047161
# 19       maryland        0.029902
# 43           utah       -0.047098
# 9         georgia        0.059826
# 45       virginia        0.038792
# 4      california        0.106082
# 29      newjersey        0.027670
# 42          texas        0.054996
# 0         alabama        0.044549
# 13        indiana        0.082684
# 41      tennessee       -0.067610
# 32  northcarolina       -0.041716
# 7        delaware       -0.027596
# 3        arkansas       -0.032559
# 8         florida        0.056152
# 16       kentucky       -0.049888
# 31        newyork        0.029075
# 27         nevada       -0.995241
# 12       illinois        0.033720
# 37   pennsylvania       -0.010047
# 30      newmexico        0.008290
# 6     connecticut       -0.014614
# 2         arizona       -0.233436
# ...

# %%
df = df[df['state'] != 'nevada'].copy()

# %%
df[['state', 'responsibilism']]
# Out:
#             state  responsibilism
# 0         alabama        0.044549
# 1          alaska       -0.121725
# 2         arizona       -0.233436
# 3        arkansas       -0.032559
# 4      california        0.106082
# 5        colorado       -0.064561
# 6     connecticut       -0.014614
# 7        delaware       -0.027596
# 8         florida        0.056152
# 9         georgia        0.059826
# 10         hawaii        0.018659
# 11          idaho       -0.010632
# 12       illinois        0.033720
# 13        indiana        0.082684
# 14           iowa       -0.122317
# 15         kansas       -0.039890
# 16       kentucky       -0.049888
# 17      louisiana       -0.088918
# 18          maine        0.039627
# 19       maryland        0.029902
# 20  massachusetts       -0.060521
# 21       michigan       -0.028592
# 22      minnesota        0.058838
# 23    mississippi        0.047161
# 24       missouri        0.062282
# 25        montana       -0.014256
# ...

# %%
df[['vandellocohencollectivismscore', 'valenceavg', 'responsibilism', 'fuzzy_collectivism', 'responsibilism_v1', 'responsibilism_v2', 'fuzzy_collectivism_v1']].corr()
# Out:
#                                 vandellocohencollectivismscore  valenceavg  \
# vandellocohencollectivismscore                        1.000000   -0.180101
# valenceavg                                           -0.180101    1.000000
# responsibilism                                        0.209397   -0.346986
# fuzzy_collectivism                                   -0.068500    0.349349
# responsibilism_v1                                     0.277355   -0.412657
# responsibilism_v2                                     0.317239   -0.484065
# fuzzy_collectivism_v1                                -0.048668   -0.122380
#
#                                 responsibilism  fuzzy_collectivism  \
# vandellocohencollectivismscore        0.209397           -0.068500
# valenceavg                           -0.346986            0.349349
# responsibilism                        1.000000           -0.024064
# fuzzy_collectivism                   -0.024064            1.000000
# ...
